# %%
# !pip3 install mtcnn --user
# Out:
# Collecting mtcnn
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.0.9
# You are using pip version 8.1.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## For single face detection

# %%
# face detection with mtcnn on a photograph
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN
# %matplotlib inline
# load image from your local directory
pixels = pyplot.imread('123.jpg')
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
print("Number of face :",len(faces))
print()
print("Cordinates details :",faces)
print()
print("Confidence score:",float(faces[0]['confidence'])*100,"percent")
# plot the image
pyplot.imshow(pixels)
# get the context for drawing boxes
ax = pyplot.gca()
# get coordinates from the first face
x, y, width, height = faces[0]['box']
a,b = faces[0]['keypoints']['nose']
c,d = faces[0]['keypoints']['left_eye']
e,f = faces[0]['keypoints']['right_eye']
# create the shape
rect2 = Rectangle((a, b), 15, 15, fill=True, color='red')
rect3 = Rectangle((c, d), 10, 10, fill=True, color='blue')
rect4 = Rectangle((e, f), 10, 10, fill=True, color='blue')
rect = Rectangle((x, y), width, height, fill=False, color='red')
# draw the box
ax.add_patch(rect)
ax.add_patch(rect2)
ax.add_patch(rect3)
ax.add_patch(rect4)
# show the plot
pyplot.show()
# Out:
# Number of face : 1
#
# Cordinates details : [{'box': [361, 74, 190, 263], 'keypoints': {'right_eye': (451, 189), 'mouth_right': (453, 280), 'left_eye': (376, 183), 'nose': (381, 242), 'mouth_left': (382, 275)}, 'confidence': 0.9999994039535522}]
#
# Confidence score: 99.99994039535522 percent

# %% [markdown]
# ## For Multiple faces detection

# %%
# face detection with mtcnn on a photograph
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN
# %matplotlib inline
# load image from file
pixels = pyplot.imread('group.jpg')
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# print(faces)
print(len(faces))
# plot the image
pyplot.imshow(pixels)
# get the context for drawing boxes
ax = pyplot.gca()
# get coordinates from the first face
for i in range(len(faces)):
    x, y, width, height = faces[i]['box']
    a,b = faces[i]['keypoints']['nose']
    c,d = faces[i]['keypoints']['left_eye']
    e,f = faces[i]['keypoints']['right_eye']
    # create the shape
    rect2 = Rectangle((a, b), 15, 15, fill=True, color='red')
    rect3 = Rectangle((c, d), 10, 10, fill=True, color='blue')
    rect4 = Rectangle((e, f), 10, 10, fill=True, color='blue')
    rect = Rectangle((x, y), width, height, fill=False, color='red')
    # draw the box
    ax.add_patch(rect)
    ax.add_patch(rect2)
    ax.add_patch(rect3)
    ax.add_patch(rect4)
# show the plot
pyplot.show()
# Out:
# 4

# %% [markdown]
# ## Calculate Number of person in an image using mtcnn

# %%
# face detection with mtcnn on a photograph
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN
# %matplotlib inline
# load image from file
pixels = pyplot.imread('group4.jpg')
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
print("Number of person in this images are : {}".format(len(faces)))
pyplot.imshow(pixels)
# Out:
# Number of person in this images are : 5

# %% [markdown]
# ## down side of this alogorithm

# %%
# face detection with mtcnn on a photograph
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN
# %matplotlib inline
# load image from file
pixels = pyplot.imread('group5.jpeg')
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# print(faces)
print(len(faces))
# plot the image
pyplot.imshow(pixels)
# get the context for drawing boxes
ax = pyplot.gca()
# get coordinates from the first face
for i in range(len(faces)):
    x, y, width, height = faces[i]['box']
    a,b = faces[i]['keypoints']['nose']
    c,d = faces[i]['keypoints']['left_eye']
    e,f = faces[i]['keypoints']['right_eye']
    # create the shape
    rect2 = Rectangle((a, b), 15, 15, fill=True, color='red')
    rect3 = Rectangle((c, d), 10, 10, fill=True, color='blue')
    rect4 = Rectangle((e, f), 10, 10, fill=True, color='blue')
    rect = Rectangle((x, y), width, height, fill=False, color='red')
    # draw the box
    ax.add_patch(rect)
    ax.add_patch(rect2)
    ax.add_patch(rect3)
    ax.add_patch(rect4)
# show the plot
pyplot.show()
# Out:
# 1

# %% [markdown]
# ### As you saw above image , mtcnn did not perform well in pictures where people do not look at the camera !!!
